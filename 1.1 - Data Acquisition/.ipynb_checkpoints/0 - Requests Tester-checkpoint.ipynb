# %% [markdown]
# #### This is the code to get all the wine links.

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import pickle
import time, os

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
base_url = 'https://www.wine.com/list/wine/7155'
response = requests.get(base_url)
response.status_code
##Start = https://www.wine.com/list/wine/7155?showOutOfStock=false
##End = https://www.wine.com/list/wine/7155/660?showOutOfStock=false
##7715
# Out:
# 200

# %%
##backup
base_url = 'https://www.shopwinedirect.com/'
response = requests.get(base_url)
response.status_code
#3500
# Out:
# 200
