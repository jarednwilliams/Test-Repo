# %% [markdown]
# Getting All Product Links
#     Step 1 - Iterate through list of basepage links, need to figure out if there are any delay requirements
#     Step 2 - For each item in the list iterate through list of products
#     Step 3 - Append Product Links to a list (2500 products per list)

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import pickle
import time, os
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from

# %% [markdown]
# #### Creating List of Base Page Links from which the Products come from

# %%
base_page_link_list = []
for i in range(661):
    base_page_link_list.append('https://www.wine.com/list/wine/7155/'+str(i)+'?showOutOfStock=false')
base_page_link_list[:5]
# Out:
# ['https://www.wine.com/list/wine/7155/0?showOutOfStock=false',
#  'https://www.wine.com/list/wine/7155/1?showOutOfStock=false',
#  'https://www.wine.com/list/wine/7155/2?showOutOfStock=false',
#  'https://www.wine.com/list/wine/7155/3?showOutOfStock=false',
#  'https://www.wine.com/list/wine/7155/4?showOutOfStock=false']

# %% [markdown]
# #### Initalize Web Driver from Selenium

# %%
chromedrive = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedrive
driver = webdriver.Chrome(chromedrive)

# %% [markdown]
# #### Creating Get Product Links Function

# %%
def base_url(url):
    driver.get(url)
    response = requests.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    all_base_content = soup.find_all('li', class_ = "prodItem")
    bottle_page_links = []
    
    for  div in all_base_content:
        for div1 in div.find_all('div', class_ = "prodItemInfo"):
            for links in div1.find_all('a'):
                link = links.get("href")
                bottle_page_links.append(link)
                
    for i in bottle_page_links:
        if i == "#":
            bottle_page_links.remove(i)
    
    updated_bottle_page_links = []
    for i in bottle_page_links:
        updated_bottle_page_links.append('https://www.wine.com' + i)
    
    return updated_bottle_page_links

# %%
### Setting Base URL and initalizing beautiful soup page and checking response code
base_url = 'https://www.wine.com/list/wine/7155?showOutOfStock=false'
driver.get(base_url)
response = requests.get(base_url)
soup = BeautifulSoup(driver.page_source, 'html.parser')
response.status_code
# Out:
# 200

# %%
### Initalizing Base Page Link of Bottles
all_base_content = soup.find_all('li', class_ = "prodItem")
bottle_page_links = []

### Parsing Base Page Products for Links of Bottles
for  div in all_base_content:
    for div1 in div.find_all('div', class_ = "prodItemInfo"):
        ## could consider creating a list in the above cell for this one called like all_base_content_grids
        for links in div1.find_all('a'):
            link = links.get("href")
            bottle_page_links.append(link)

### Removing weird '#'
for i in bottle_page_links:
    if i == "#":
        bottle_page_links.remove(i)

updated_bottle_page_links = []
for i in bottle_page_links:
    updated_bottle_page_links.append('https://www.wine.com' + i)

updated_bottle_page_links
# Out:
# ['https://www.wine.com/product/joseph-phelps-insignia-2018/783452',
#  'https://www.wine.com/product/veuve-clicquot-yellow-label-brut/528',
#  'https://www.wine.com/product/joseph-phelps-freestone-vineyards-pinot-noir-2019/716789',
#  'https://www.wine.com/product/silver-oak-alexander-valley-cabernet-sauvignon-2017/671253',
#  'https://www.wine.com/product/rombauer-chardonnay-2020/745112',
#  'https://www.wine.com/product/vina-robles-estate-cabernet-sauvignon-2019/854917',
#  'https://www.wine.com/product/robert-mondavi-to-kalon-vineyard-reserve-cabernet-sauvignon-2016/543734',
#  'https://www.wine.com/product/the-prisoner-wine-company-the-prisoner-red-blend-2019/673519',
#  'https://www.wine.com/product/joseph-phelps-freestone-vineyards-chardonnay-2019/782475',
#  'https://www.wine.com/product/stags-leap-wine-cellars-artemis-cabernet-sauvignon-2019/874274',
#  'https://www.wine.com/product/joseph-phelps-cabernet-sauvignon-2019/782060',
# ...

# %%
print(len(bottle_page_links))
### 25 results per, so 655 pages*25 results per page
# Out:
# 25

# %%
### probably should be pickling every 100 pages or every 2500 results!

with open('base_page_links_test.pkl', 'wb') as f: 
    pickle.dump(base_page_links, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7963b30dc7d7> in <module>
#       2
#       3 with open('base_page_links_test.pkl', 'wb') as f:
# ----> 4     pickle.dump(base_page_links, f)
#
# NameError: name 'base_page_links' is not defined

# %% [markdown]
# #### Creating Get Product Links Function

# %%
def base_url(url):
    driver.get(url)
    response = requests.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    all_base_content = soup.find_all('li', class_ = "prodItem")
    bottle_page_links = []
    
    for  div in all_base_content:
        for div1 in div.find_all('div', class_ = "prodItemInfo"):
            for links in div1.find_all('a'):
                link = links.get("href")
                bottle_page_links.append(link)
                
    for i in bottle_page_links:
        if i == "#":
            bottle_page_links.remove(i)
    
    updated_bottle_page_links = []
    for i in bottle_page_links:
        updated_bottle_page_links.append('https://www.wine.com' + i)
    
    return updated_bottle_page_links

# %%
###test
empty_list = []
empty_list.extend(base_url(base_page_link_list[1]))
empty_list.extend(base_url(base_page_link_list[2]))
empty_list.extend(base_url(base_page_link_list[3]))
empty_list.extend(base_url(base_page_link_list[4]))
empty_list
# Out:
# ['https://www.wine.com/product/joseph-phelps-insignia-2018/783452',
#  'https://www.wine.com/product/dom-perignon-vintage-2012/766906',
#  'https://www.wine.com/product/veuve-clicquot-yellow-label-brut/528',
#  'https://www.wine.com/product/joseph-phelps-freestone-vineyards-pinot-noir-2019/716789',
#  'https://www.wine.com/product/silver-oak-alexander-valley-cabernet-sauvignon-2017/671253',
#  'https://www.wine.com/product/rombauer-chardonnay-2020/745112',
#  'https://www.wine.com/product/vina-robles-estate-cabernet-sauvignon-2019/854917',
#  'https://www.wine.com/product/robert-mondavi-to-kalon-vineyard-reserve-cabernet-sauvignon-2016/543734',
#  'https://www.wine.com/product/the-prisoner-wine-company-the-prisoner-red-blend-2019/673519',
#  'https://www.wine.com/product/joseph-phelps-freestone-vineyards-chardonnay-2019/782475',
#  'https://www.wine.com/product/stags-leap-wine-cellars-artemis-cabernet-sauvignon-2019/874274',
# ...

# %%
#### Scraping to get Empty List
product_list = []
counter = 0
for page in base_page_link_list[:5]:
    product_list.extend(base_url(page))
    counter += 1
    if counter%2 == 0:
        with open('product_links_test', 'w') as f: 
            f.write(str(product_list))
    time.sleep(10)
    #### I need to pickle this after 100 loops (i'll do 2 loops as a test)

# %%
product_list
# Out:
# ['https://www.wine.com/product/joseph-phelps-insignia-2018/783452',
#  'https://www.wine.com/product/dom-perignon-vintage-2012/766906',
#  'https://www.wine.com/product/veuve-clicquot-yellow-label-brut/528',
#  'https://www.wine.com/product/joseph-phelps-freestone-vineyards-pinot-noir-2019/716789',
#  'https://www.wine.com/product/silver-oak-alexander-valley-cabernet-sauvignon-2017/671253',
#  'https://www.wine.com/product/rombauer-chardonnay-2020/745112',
#  'https://www.wine.com/product/vina-robles-estate-cabernet-sauvignon-2019/854917',
#  'https://www.wine.com/product/robert-mondavi-to-kalon-vineyard-reserve-cabernet-sauvignon-2016/543734',
#  'https://www.wine.com/product/the-prisoner-wine-company-the-prisoner-red-blend-2019/673519',
#  'https://www.wine.com/product/joseph-phelps-freestone-vineyards-chardonnay-2019/782475',
#  'https://www.wine.com/product/stags-leap-wine-cellars-artemis-cabernet-sauvignon-2019/874274',
# ...

# %%
test_1 = open('product_links_test','w')
for i in product_list:
/521857', 'https://www.wine.com/product/hampton-water-rose-2020/716058', 'https://www.wine.com/product/chateau-castera-2015/507814', 'https://www.wine.com/product/antinori-villa-antinori-chianti-classico-riserva-2017/723748', 'https://www.wine.com/product/chateau-faizeau-montagne-st-emilion-2018/665072', 'https://www.wine.com/product/domaine-du-vieux-telegraphe-chateauneuf-du-pape-la-crau-2019/858947', 'https://www.wine.com/product/kim-crawford-sauvignon-blanc-2021/783558', 'https://www.wine.com/product/stags-leap-wine-cellars-karia-chardonnay-2019/774644', 'https://www.wine.com/product/clos-de-los-siete-red-blend-2018/757913', 'https://www.wine.com/product/conundrum-red-blend-2019/738527', 'https://www.wine.com/product/j-lohr-estates-riverstone-chardonnay-2020/781968', 'https://www.wine.com/product/bogle-old-vines-zinfandel-2019/712458', 'https://www.wine.com/product/haras-de-pirque-hussonet-gran-reserva-cabernet-sauvignon-2018/741484', 'https://www.wine.com/product/hahn-slh-pinot-noir-2019/749913', 'https://www.wine.com/product/antinori-villa-toscana-2018/735899', 'https://www.wine.com/product/miraval-rose-2020/728701', 'https://www.wine.com/product/chateau-greysac-2014/433955', 'https://www.wine.com/product/bogle-chardonnay-2020/750018', 'https://www.wine.com/product/kendall-jackson-grand-reserve-chardonnay-2019/692651', 'https://www.wine.com/product/benmarco-malbec-2019/751875', 'https://www.wine.com/product/bouchard-pere-and-fils-reserve-bourgogne-pinot-noir-2019/712067', 'https://www.wine.com/product/parducci-small-lot-pinot-noir-2020/804044', 'https://www.wine.com/product/oyster-bay-marlborough-sauvignon-blanc-2021/780105', 'https://www.wine.com/product/columbia-crest-h3-cabernet-sauvignon-2018/693802', 'https://www.wine.com/product/zuccardi-q-malbec-2019/675909', 'https://www.wine.com/product/double-canyon-horse-heaven-hills-cabernet-sauvignon-2017/721282', 'https://www.wine.com/product/la-braccesca-vino-nobile-di-montepulciano-2017/746318', 'https://www.wine.com/product/chateau-hyot-2016/782312', 'https://www.wine.com/product/au-contraire-sonoma-coast-pinot-noir-2017/578335', 'https://www.wine.com/product/le-grand-courtage-blanc-de-blancs-brut/137803', 'https://www.wine.com/product/antinori-pian-delle-vigne-brunello-di-montalcino-2016/841746', 'https://www.wine.com/product/cedar--salmon-willamette-valley-pinot-gris-2020/781677', 'https://www.wine.com/product/piancornello-brunello-di-montalcino-2016/714558', 'https://www.wine.com/product/chateau-ferran-2018/520449', 'https://www.wine.com/product/hahn-founders-pinot-noir-2019/711234', 'https://www.wine.com/product/columbia-crest-grand-estates-chardonnay-2017/627078', 'https://www.wine.com/product/matua-sauvignon-blanc-2021/819175', 'https://www.wine.com/product/ancient-peaks-paso-robles-cabernet-sauvignon-2019/758683', 'https://www.wine.com/product/louis-jadot-beaujolais-villages-2020/719036']

# %%
len(test_of_txt_file)
# Out:
# 125

# %%
len(set(test_of_txt_file))
# Out:
# 75

# %%
    if counter%2 == 0:
        with open('product_links_test', 'w') as f: 
            f.write(str(product_list))
    time.sleep(randint(10,100))

# %% [markdown]
# 1) going to scrape 2500 bottles links at a time an dmake sure they're not duplicated! sucks, but I dont wanna waste more time with this!
#
# 1.5) After a break I will make sure to create a seperate notebook and seperate lins for reach of the 6-7 times I will scrape
#
# 2) Once I have all the bottle links today I'll I'll start scraping data! Should have about 6-7 txt files of links

# %% [markdown]
# product_list
