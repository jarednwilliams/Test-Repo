# %%
import pandas as pd
import csv

# %%
products_1 = pd.read_csv('products_1.csv')
products_2 = pd.read_csv('products_2.csv')
products_3 = pd.read_csv('products_3.csv')
products_4 = pd.read_csv('products_4.csv')

# %%
product_df_list = [products_2, products_3, products_4]
products = products_1
for df in product_df_list:
    products = products.append(df)

# %%
products.shape
# Out:
# (16352, 8)

# %%
products.to_csv('products.csv', index=False)
